# %%
import pandas as pd

# %% [markdown]
# ### **unit data sheet**

# %%
unitdata_df = pd.read_excel('/Users/sophiekim/Desktop/msds/ds 5030/project/emissions_by_unit_and_fuel_type_c_d_aa.xlsb', engine='pyxlsb', skiprows=6, sheet_name='UNIT_DATA')

unitdata_df.head()
# Out:
#    Facility Id        FRS Id  \
# 0      1001155  1.100004e+11
# 1      1012147           NaN
# 2      1012147           NaN
# 3      1012147           NaN
# 4      1012147           NaN
#
#                                        Facility Name          City State  \
# 0  1500 South Tibbs LLC d/b/a Aurorium Indianapol...  Indianapolis    IN
# 1                   17Z Gas Plant - Chevron USA Inc.    McKittrick    CA
# 2                   17Z Gas Plant - Chevron USA Inc.    McKittrick    CA
# 3                   17Z Gas Plant - Chevron USA Inc.    McKittrick    CA
# 4                   17Z Gas Plant - Chevron USA Inc.    McKittrick    CA
#
#    Primary NAICS Code  Reporting Year Industry Type (subparts)  \
# 0            325199.0            2023                        C
# 1            211130.0            2018                   C,NN,W
# 2            211130.0            2018                   C,NN,W
# 3            211130.0            2018                   C,NN,W
# ...

# %%
unitdata_df.columns
# Out:
# Index(['Facility Id', 'FRS Id', 'Facility Name', 'City', 'State',
#        'Primary NAICS Code', 'Reporting Year', 'Industry Type (subparts)',
#        'Industry Type (sectors)', 'Unit Name', 'Unit Type',
#        'Unit Reporting Method',
#        'Unit Maximum Rated Heat Input Capacity (mmBTU/hr)',
#        'Unit CO2 emissions (non-biogenic) ', 'Unit Methane (CH4) emissions ',
#        'Unit Nitrous Oxide (N2O) emissions ',
#        'Unit Biogenic CO2 emissions (metric tons)'],
#       dtype='object')

# %%
unitdata_df['Unit Type'] = unitdata_df['Unit Type'].astype(str).str.strip()

# %%
# group by industry type & summing by all the emissions

emissions_cols = ['Unit CO2 emissions (non-biogenic) ', 'Unit Methane (CH4) emissions ',
       'Unit Nitrous Oxide (N2O) emissions ',
       'Unit Biogenic CO2 emissions (metric tons)']


emissions_by_unit = unitdata_df.groupby('Unit Type')[emissions_cols].sum()
emissions_by_unit
# Out:
#                                                     Unit CO2 emissions (non-biogenic)   \
# Unit Type
# BFB (Boiler, bubbling fluidized bed)                                      7.501641e+06
# C (Calciner)                                                              2.088842e+07
# CCCT (CC (Turbine, combined cycle))                                       3.271796e+08
# CF (Cyclone Furnace)                                                      3.656796e+06
# CFB (Boiler, circulating fluidized bed)                                   2.288699e+08
# CH (Comfort heater)                                                       1.373336e+06
# COB (By-product recovery coke oven battery comb...                        4.658214e+06
# CatH (Heater,  catalytic)                                                 1.515756e+05
# Chemical Recovery Combustion Unit                                         9.804860e+05
# Chemical Recovery Furnace                                                 2.219857e+07
# ...

# %%
unitdata_df['Facility Name'].value_counts()
# Out:
# Facility Name
# THE GEORGE WASHINGTON UNIVERSITY                        1146
# University of Arizona                                   1125
# HILL AIR FORCE BASE: MAIN BASE                          1046
# MOTIVA ENTERPRISES LLC                                  1010
# Mont Belvieu Complex                                     913
#                                                         ...
# TARGA ROCKER B COMPRESSOR STATION                          1
# Cheyenne Central Processing Facility                       1
# Pinnacle Dos Picos Gas Plant                               1
# Pinehill Landfill                                          1
# 1500 South Tibbs LLC d/b/a Aurorium Indianapolis LLC       1
# Name: count, Length: 8595, dtype: int64

# %%
emissions_by_facility = unitdata_df.groupby('Facility Name')[emissions_cols].sum()
emissions_by_facility
# Out:
#                                                     Unit CO2 emissions (non-biogenic)   \
# Facility Name
# 1500 South Tibbs LLC d/b/a Aurorium Indianapoli...                             64740.5
# 17Z Gas Plant - Chevron USA Inc.                                               22508.2
# 23rd and 3rd                                                                  821973.3
# 29-6 #2 Central Delivery Point                                                 75504.1
# 30-30 Gas Plant                                                                69521.3
# ...                                                                                ...
# Zion Energy Center                                                           2687912.7
# Zuni                                                                          199692.3
# voestalpine Texas                                                              35497.8
# voestalpine Texas LLC                                                         134027.9
# ...

# %%
emissions_by_state = unitdata_df.groupby('State')[emissions_cols].sum()
emissions_by_state
# Out:
#        Unit CO2 emissions (non-biogenic)   Unit Methane (CH4) emissions   \
# State
# AK                           1.938444e+08                   1.426098e+05
# AL                           9.327701e+08                   2.123092e+06
# AR                           4.814009e+08                   1.231419e+06
# AZ                           6.157479e+08                   1.251864e+06
# CA                           8.910454e+08                   7.356070e+05
# CO                           5.147126e+08                   6.113235e+05
# CT                           1.245735e+08                   2.637634e+05
# DC                           3.622566e+06                   1.967000e+03
# DE                           6.723827e+07                   5.983488e+04
# FL                           1.412109e+09                   2.823613e+06
# GA                           7.884418e+08                   2.005269e+06
# GU                           1.565204e+07                   1.530425e+04
# ...

# %% [markdown]
# ### **fuel data sheet**

# %%
fueldata_df = pd.read_excel('/Users/sophiekim/Desktop/msds/ds 5030/project/emissions_by_unit_and_fuel_type_c_d_aa.xlsb', engine='pyxlsb', skiprows=5, sheet_name='FUEL_DATA')

fueldata_df
# Out:
#         Facility Id        FRS Id  \
# 0           1001155  1.100004e+11
# 1           1001155  1.100004e+11
# 2           1012147           NaN
# 3           1012147           NaN
# 4           1012147           NaN
# ...             ...           ...
# 323491      1003318  1.100438e+11
# 323492      1003318  1.100438e+11
# 323493      1003318  1.100438e+11
# 323494      1003318  1.100438e+11
# 323495      1003318  1.100438e+11
#
#                                             Facility Name          City State  \
# 0       1500 South Tibbs LLC d/b/a Aurorium Indianapol...  Indianapolis    IN
# 1       1500 South Tibbs LLC d/b/a Aurorium Indianapol...  Indianapolis    IN
# 2                        17Z Gas Plant - Chevron USA Inc.    McKittrick    CA
# 3                        17Z Gas Plant - Chevron USA Inc.    McKittrick    CA
# 4                        17Z Gas Plant - Chevron USA Inc.    McKittrick    CA
# ...                                                   ...           ...   ...
# ...

# %%
fueldata_df.columns
# Out:
# Index(['Facility Id', 'FRS Id', 'Facility Name', 'City', 'State',
#        'Primary NAICS Code', 'Reporting Year', 'Industry Type (subparts)',
#        'Industry Type (sectors)', 'Unit Name', 'General Fuel Type',
#        'Specific Fuel Type', 'Other Fuel Name', 'Blend Fuel Name',
#        'Fuel Methane (CH4) emissions (mt CO2e)',
#        'Fuel Nitrous Oxide (N2O) emissions (mt CO2e)'],
#       dtype='object')

# %%
fueldata_df['General Fuel Type'].value_counts()
# Out:
# General Fuel Type
# Natural Gas           185963
# Petroleum Products     84954
# Other                  37379
# Coal                   15149
# Fuel Gas                  17
# Natural Gas                2
# Biomass                    2
# Solid Byproducts           1
# Name: count, dtype: int64

# %%
fuel_cols = ['Fuel Methane (CH4) emissions (mt CO2e)',
       'Fuel Nitrous Oxide (N2O) emissions (mt CO2e)']

emissions_by_fuel = fueldata_df.groupby('General Fuel Type')[fuel_cols].sum()
emissions_by_fuel
# Out:
#                     Fuel Methane (CH4) emissions (mt CO2e)  \
# General Fuel Type
# Biomass                                       4.000000e+00
# Coal                                          3.810367e+07
# Fuel Gas                                      2.026750e+03
# Natural Gas                                   5.313865e+06
# Natural Gas                                   1.032500e+02
# Other                                         1.047312e+07
# Petroleum Products                            5.193649e+05
# Solid Byproducts                              0.000000e+00
#
#                     Fuel Nitrous Oxide (N2O) emissions (mt CO2e)
# General Fuel Type
# Biomass                                             4.768000e+00
# Coal                                                8.239497e+07
# Fuel Gas                                            4.829090e+03
# Natural Gas                                         6.338404e+06
# Natural Gas                                         1.230740e+02
# ...

# %%
fueldata_df['Facility Name'].value_counts()
# Out:
# Facility Name
# THE GEORGE WASHINGTON UNIVERSITY       1232
# HILL AIR FORCE BASE: MAIN BASE         1151
# University of Arizona                  1125
# MOTIVA ENTERPRISES LLC                 1058
# Mont Belvieu Complex                    919
#                                        ...
# North Canton Compressor Station           1
# KaMin LLC - Edgar                         1
# TARGA ROCKER B COMPRESSOR STATION         1
# LIVE OAK LANDFILL & RECYLING CENTER       1
# Wellhead Power Gates, LLC                 1
# Name: count, Length: 8595, dtype: int64

# %%
fuels_by_facility = fueldata_df.groupby('Facility Name')[fuel_cols].sum()
fuels_by_facility
# Out:
#                                                     Fuel Methane (CH4) emissions (mt CO2e)  \
# Facility Name
# 1500 South Tibbs LLC d/b/a Aurorium Indianapoli...                                   30.50
# 17Z Gas Plant - Chevron USA Inc.                                                     10.50
# 23rd and 3rd                                                                        383.50
# 29-6 #2 Central Delivery Point                                                       35.50
# 30-30 Gas Plant                                                                      32.50
# ...                                                                                    ...
# Zion Energy Center                                                                 1248.25
# Zuni                                                                                 92.50
# voestalpine Texas                                                                    16.75
# ...

# %% [markdown]
# ---
